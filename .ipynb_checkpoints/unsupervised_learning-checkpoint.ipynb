# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# Import statements

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import mixture
from sklearn import preprocessing
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import train_test_split
import pylab as pl
from sklearn.decomposition import PCA
from pandas.tools.plotting import scatter_matrix
from IPython.core.interactiveshell import InteractiveShell
from IPython.display import display, HTML
from plot_kmeans_silhouette_analysis import print_silhouette_analysis

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# Read in data files

# %%
hr_df = pd.read_csv('data/HR_comma_sep.csv')
letter_df = pd.read_csv('data/letter-recognition.csv')

# %% [markdown]
# Clean up the hr dataset

# %%
# vectorize string columns
vectorized_sales = pd.get_dummies(hr_df['sales'])
vectorized_salary = pd.get_dummies(hr_df['salary'])

# add vectorized columns to the original dataframe and drop the old columns
hr_df = pd.concat([hr_df, vectorized_salary, vectorized_sales], axis=1)
hr_df.drop('sales', axis=1, inplace=True)
hr_df.drop('salary', axis=1, inplace=True)

# move the Y column (left) to the end of the dataframe for readability
y_hr = hr_df['left']
hr_df.drop('left', axis=1, inplace=True)
hr_df = pd.concat([hr_df, y_hr], axis=1)

# %% [markdown]
# Clean up the letter dataset

# %%
# label binarizer for the multi class output
lb = preprocessing.LabelBinarizer()
lb.fit(letter_df.ix[:, 0:1])
y_letter = lb.transform(letter_df.ix[:, 0:1])

# %% [markdown]
# Split test/training

# %%
# split up the training and test data before we start doing anything so we don't generate bias in the experiments
X_train_hr, X_test_hr, y_train_hr, y_test_hr = train_test_split(hr_df.ix[:,:-1], hr_df.ix[:,-1:], test_size=0.3, random_state=42)
y_train_hr = y_train_hr.values.ravel()
y_test_hr = y_test_hr.values.ravel()

# %%
X_train_letter, X_test_letter, y_train_letter, y_test_letter = train_test_split(letter_df.ix[:, 1:], y_letter, test_size=0.3, random_state=42)

# %% [markdown]
# ## Cluster analysis

# %% [markdown]
# ### Human Resources

# %% [markdown]
# #### K-means

# %%
silhouette_scores = []
for i in range(2,7):
    kmeans = KMeans(n_clusters=i, random_state=0).fit(X_train_hr)
    labels = kmeans.labels_
    silhouette_scores.append(silhouette_score(X_train_hr, labels, metric='euclidean'))

# %%
scores_df = pd.DataFrame(silhouette_scores, columns=['Silhouette Scores'], index=range(2,7))
scores_df.plot()
plt.show()

# %%
# silhouette analysis
print_silhouette_analysis(X_train_hr.values)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.645436427715
# For n_clusters = 3 The average silhouette_score is : 0.584369490879
# For n_clusters = 4 The average silhouette_score is : 0.539500913022
# For n_clusters = 5 The average silhouette_score is : 0.502207213021
# For n_clusters = 6 The average silhouette_score is : 0.49380740729

# %%
# visualize the distribution of data by using the best k value
kmeans = KMeans(n_clusters=2, random_state=0).fit(X_train_hr)
labels = kmeans.labels_

for feature in X_train_hr.columns:
    ax = X_train_hr[feature].hist(figsize=(5,5), bins=20, by=(labels, y_train_hr), sharex=True, sharey=True)
    pl.suptitle(feature)
    
plt.show()

# %% [markdown]
# #### EM

# %%
silhouette_scores = []
for i in range(2,7):
    gmm = mixture.GaussianMixture(n_components=i, covariance_type='spherical')
    gmm.fit(X_train_hr)
    labels = gmm.predict(X_train_hr)
    silhouette_scores.append(silhouette_score(X_train_hr, labels, metric='euclidean'))

# %%
scores_df = pd.DataFrame(silhouette_scores, columns=['Silhouette Scores'], index=range(2,7))
scores_df.plot()
plt.show()

# %%
# silhouette analysis
print_silhouette_analysis(X_train_hr.values, clustering='em')
# Out:
# For n_clusters = 2 The average silhouette_score is : -0.0213485211666
# For n_clusters = 3 The average silhouette_score is : -0.0213485211666
# For n_clusters = 4 The average silhouette_score is : -0.0213485211666
# For n_clusters = 5 The average silhouette_score is : -0.0213485211666
# For n_clusters = 6 The average silhouette_score is : -0.0213485211666

# %%
# visualize the distribution of data by using the best k value
gmm = mixture.GaussianMixture(n_components=2, covariance_type='spherical')
gmm.fit(X_train_hr)
labels = gmm.predict(X_train_hr)

for feature in X_train_hr.columns:
    ax = X_train_hr[feature].hist(figsize=(5,5), bins=20, by=labels, sharex=True, sharey=True)
    pl.suptitle(feature)
    
plt.show()

# %% [markdown]
# ### Letter Recognition

# %% [markdown]
# #### K-means

# %%
silhouette_scores = []
for i in range(2,20):
    kmeans = KMeans(n_clusters=i, random_state=0).fit(X_train_letter)
    labels = kmeans.labels_
    silhouette_scores.append(silhouette_score(X_train_letter, labels, metric='euclidean'))

# %%
scores_df = pd.DataFrame(silhouette_scores, columns=['Silhouette Scores'], index=range(2,20))
scores_df.plot()
plt.show()

# %%
# silhouette analysis
print_silhouette_analysis(X_train_letter.values)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.17426347187
# For n_clusters = 3 The average silhouette_score is : 0.157080032357
# For n_clusters = 4 The average silhouette_score is : 0.138868823275
# For n_clusters = 5 The average silhouette_score is : 0.142044064984
# For n_clusters = 6 The average silhouette_score is : 0.148976917123

# %%
# visualize the distribution of data by using the best k value
kmeans = KMeans(n_clusters=2, random_state=0).fit(X_train_letter)
labels = kmeans.labels_

for feature in X_train_letter.columns:
    ax = X_train_letter[feature].hist(figsize=(5,5), bins=20, by=labels, sharex=True, sharey=True)
    pl.suptitle(feature)
    
plt.show()

# %% [markdown]
# #### EM

# %% [markdown]
# ## Dimensionality reduction analysis

# %% [markdown]
# ### Human Resources

# %% [markdown]
# #### PCA

# %%
pca = PCA()
pca.fit(X_train_hr)

df = pd.DataFrame(pca.explained_variance_, index=X_train_hr.columns)
df.plot(kind='bar')
plt.show()

# %% [markdown]
# #### ICA

# %% [markdown]
# #### RCA

# %% [markdown]
# #### k-best

# %% [markdown]
# ### Letter Recognition

# %% [markdown]
# #### PCA

# %%
pca = PCA()
pca.fit(X_train_letter)

df = pd.DataFrame(pca.explained_variance_, index=X_train_letter.columns)
df.plot(kind='bar')
plt.show()

# %% [markdown]
# #### ICA

# %% [markdown]
# #### RCA

# %% [markdown]
# #### k-best
